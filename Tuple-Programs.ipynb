# %% [markdown]
# <a href="https://colab.research.google.com/github/pranali-b26/Python-Programs-Practice/blob/main/Tuple-Programs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
t = (10, "hello", 3.14)
print(t)
# Out:
# (10, 'hello', 3.14)

# %%
t = (1, 2, 3, 4, 5)
print(t[2])
# Out:
# 3

# %%
t1 = (1, 2, 3)
t2 = (4, 5, 6)
t3 = t1 + t2
print(t3)
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
t = (10, 20, 30)
a, b, c = t
print(a, b, c)
# Out:
# 10 20 30

# %%
t = (1, 3, 5, 7, 9)
print(7 in t)
# Out:
# True

# %%
t = (0, 1, 2, 3, 4, 5)
print(t[2:5])
# Out:
# (2, 3, 4)

# %%
t = (10, 20, 30, 40, 50)
print(len(t))
# Out:
# 5
