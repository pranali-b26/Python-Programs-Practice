# %% [markdown]
# <a href="https://colab.research.google.com/github/pranali-b26/Python-Programs-Practice/blob/main/Tuple-Programs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
t = (10, "hello", 3.14)
print(t)
# Out:
# (10, 'hello', 3.14)

# %%
t = (1, 2, 3, 4, 5)
print(t[2])
# Out:
# 3

# %%
t1 = (1, 2, 3)
t2 = (4, 5, 6)
t3 = t1 + t2
print(t3)
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
t = (10, 20, 30)
a, b, c = t
print(a, b, c)
# Out:
# 10 20 30

# %%
t = (1, 3, 5, 7, 9)
print(7 in t)
# Out:
# True

# %%
t = (0, 1, 2, 3, 4, 5)
print(t[2:5])
# Out:
# (2, 3, 4)

# %%
t = (10, 20, 30, 40, 50)
print(len(t))
# Out:
# 5

# %%
t = (1, 2, 3)
print(t * 3)
# Out:
# (1, 2, 3, 1, 2, 3, 1, 2, 3)

# %%
l = [1, 2, 3]
t = tuple(l)
print(t)
# Out:
# (1, 2, 3)

# %%
t = (5, 12, 3, 8, 15)
print(min(t))
print(max(t))
# Out:
# 3
# 15

# %%
t = (1, 2, 3, 2, 4, 2)
print(t.count(2))
# Out:
# 3

# %%
t = (True, True, False)
print(all(t))
# Out:
# False

# %%
t = (1, 2, 3, 4, 3, 5)
print(t.index(3))
# Out:
# 2

# %%
t = (5, 2, 8, 1, 3)
new_t = tuple(sorted(t))
print(new_t)
# Out:
# (1, 2, 3, 5, 8)

# %%
t = tuple(i*i for i in range(1, 6))
print(t)
# Out:
# (1, 4, 9, 16, 25)

# %%
t = tuple(i*i for i in range(1,6))
print(t)
# Out:
# (1, 4, 9, 16, 25)

# %%
t = (10, "hello", 3.14, True)
print(t)
# Out:
# (10, 'hello', 3.14, True)

# %%
t = (100, 200, 300)
print(t[0])
# Out:
# 100

# %%
t = (5, 10, 15)
a, b, c = t
print(a, b, c)
# Out:
# 5 10 15

# %%
t = (1, 2, 3)
t = t + (4,)
print(t)
# Out:
# (1, 2, 3, 4)

# %%
t = ('P','y','t','h','o','n')
s = ''.join(t)
print(s)
# Out:
# Python

# %%
t = (10, 20, 30, 40, 50, 60)
print(t[-4])
# Out:
# 30

# %%
t1 = (1, 2, 3)
t2 = t1
print(t2)
# Out:
# (1, 2, 3)

# %%
t = (1,2,3,2,4,3,5)
rep = set([x for x in t if t.count(x) > 1])
print(rep)
# Out:
# {2, 3}

# %%
t = (10, 20, 30)
print(20 in t)
# Out:
# True

# %%
l = [4, 5, 6]
t = tuple(l)
print(t)
# Out:
# (4, 5, 6)

# %%
t = (1, 2, 3, 4)
l = list(t)
l.remove(3)
t = tuple(l)
print(t)
# Out:
# (1, 2, 4)
