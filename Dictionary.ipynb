# %% [markdown]
# <a href="https://colab.research.google.com/github/pranali-b26/Python-Programs-Practice/blob/main/Dictionary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
d = {0:10, 1:20}
d[2] = 30
print(d)
# Out:
# {0: 10, 1: 20, 2: 30}

# %%
dic1 = {1:10, 2:20}
dic2 = {3:30, 4:40}
dic3 = {5:50, 6:60}

result = {}
result.update(dic1)
result.update(dic2)
result.update(dic3)

print(result)
# Out:
# {1: 10, 2: 20, 3: 30, 4: 40, 5: 50, 6: 60}

# %%
d = {1:10, 2:20, 3:30}
key = 2

print(key in d)
# Out:
# True

# %%
d = {1:10, 2:20, 3:30}

for key, value in d.items():
    print(key, value)
# Out:
# 1 10
# 2 20
# 3 30

# %%
n = 5
d = {}

for x in range(1, n+1):
    d[x] = x*x

print(d)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %%
d = {}

for x in range(1,16):
    d[x] = x*x

print(d)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100, 11: 121, 12: 144, 13: 169, 14: 196, 15: 225}

# %%
d1 = {'a':1, 'b':2}
d2 = {'c':3, 'd':4}

d1.update(d2)
print(d1)
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %%
d = {'a':100, 'b':200}

for k in d:
    print(k, d[k])
# Out:
# a 100
# b 200

# %%
d = {'a':10, 'b':20, 'c':30}
print(sum(d.values()))
# Out:
# 60

# %%
d = {'a':2, 'b':3, 'c':4}

result = 1
for value in d.values():
    result *= value

print(result)
# Out:
# 24

# %%
d = {'a':1, 'b':2, 'c':3}
del d['b']
print(d)
# Out:
# {'a': 1, 'c': 3}

# %%
keys = ['a','b','c']
values = [1,2,3]

d = dict(zip(keys, values))
print(d)
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
d = {3:30, 1:10, 2:20}
sorted_d = dict(sorted(d.items()))
print(sorted_d)
# Out:
# {1: 10, 2: 20, 3: 30}

# %%
d = {'a':5, 'b':12, 'c':3}

print("Max:", max(d.values()))
print("Min:", min(d.values()))
# Out:
# Max: 12
# Min: 3

# %%
class Student:
    def __init__(self):
        self.name = "Pranali"
        self.age = 20

obj = Student()
print(obj.__dict__)
# Out:
# {'name': 'Pranali', 'age': 20}

# %%
d = {'a':100, 'b':200, 'c':100}

new_d = {}
for k,v in d.items():
    if v not in new_d.values():
        new_d[k] = v

print(new_d)
# Out:
# {'a': 100, 'b': 200}

# %%
d = {}

if not d:
    print("Dictionary is empty")
# Out:
# Dictionary is empty

# %%
d1 = {'a':100, 'b':200, 'c':300}
d2 = {'a':300, 'b':200, 'd':400}

result = {}

for k in set(d1) | set(d2):
    result[k] = d1.get(k,0) + d2.get(k,0)

print(result)
# Out:
# {'a': 400, 'c': 300, 'b': 400, 'd': 400}

# %%
data = [{"V":"S001"}, {"V":"S002"}, {"VI":"S001"},
        {"VI":"S005"}, {"VII":"S005"},
        {"V":"S009"}, {"VIII":"S007"}]

unique_values = set()

for item in data:
    for value in item.values():
        unique_values.add(value)

print("Unique Values:", unique_values)
# Out:
# Unique Values: {'S009', 'S002', 'S005', 'S007', 'S001'}

# %%
from itertools import product

data = {'1': ['a','b'], '2': ['c','d']}

for combo in product(data['1'], data['2']):
    print(combo[0] + combo[1])
# Out:
# ac
# ad
# bc
# bd

# %%
d = {'a':10, 'b':50, 'c':30, 'd':20, 'e':40}

top3 = sorted(d.values(), reverse=True)[:3]
print(top3)
# Out:
# [50, 40, 30]

# %%
from collections import Counter

data = [
    {'item': 'item1', 'amount': 400},
    {'item': 'item2', 'amount': 300},
    {'item': 'item1', 'amount': 750}
]

result = Counter()

for d in data:
    result[d['item']] += d['amount']

print(result)
# Out:
# Counter({'item1': 1150, 'item2': 300})

# %%
s = "SBJAIN"

d = {}
for ch in s:
    d[ch] = d.get(ch, 0) + 1

print(d)
# Out:
# {'S': 1, 'B': 1, 'J': 1, 'A': 1, 'I': 1, 'N': 1}

# %%
d = {'Name': 'Pranali', 'Age': 20, 'City': 'Pune'}

print("Key\tValue")
for k, v in d.items():
    print(k, "\t", v)
# Out:
# Key	Value
# Name 	 Pranali
# Age 	 20
# City 	 Pune

# %%
d = {'a':[1,2,3,4,5,6], 'b':[10,20]}

print(len(d['a']))
print(len(d['b']))
# Out:
# 6
# 2

# %%
lst = ['a','b','c']

d = current = {}
for item in lst:
    current[item] = {}
    current = current[item]

print(d)
# Out:
# {'a': {'b': {'c': {}}}}

# %%
d = {'letters': ['banana','apple','cherry']}

d['letters'].sort()
print(d)
# Out:
# {'letters': ['apple', 'banana', 'cherry']}
